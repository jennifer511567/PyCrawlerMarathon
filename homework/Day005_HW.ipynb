# %%
import requests
# 引入函式庫
r = requests.get('https://www.dcard.tw/_api/forums/job/posts?popular=true')
# 想要爬資料的⽬目標網址
response = r.text
# 模擬發送請求的動作
response
# Out:
# '[{"id":225578807,"title":"<請先點我> 工作板＆實習、打工職缺刊登說明","excerpt":"工作板主要供分享職場工作心得、面試、正職、招考過程分享、各類型工作內容介紹、勞工工作權益與相關法案議題討論相關文章。文章發文後請加上話題，如：經驗分享、職業介紹、勞工權益、徵才等....，「實習職缺/刊登」請點：","anonymousSchool":false,"anonymousDepartment":true,"pinned":true,"forumId":"6eeeafb2-9dac-4d81-ae4b-ffecf0ad4444","replyId":null,"createdAt":"2017-01-01T06:27:39.650Z","updatedAt":"2020-02-27T02:54:18.710Z","commentCount":43,"likeCount":724,"withNickname":true,"tags":[],"topics":["工作板","Dcard公告","實習職缺","打工職缺"],"meta":{},"forumName":"工作","forumAlias":"job","nsfw":false,"gender":"D","school":"客服小天使","department":"dcard_support_2","replyTitle":null,"mediaMeta":[],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":720},{"id":"aa0d425f-d530-4478-9a77-fe3aedc79eea","count":2},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":2}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","pinnedType":"dcard","pinnedPriority":1582772058000,"withImages":false,"withVideos":false,"media":
# ...

# %%
import json
data = json.loads(response) 
# 利⽤ json 解析網⾴頁內容
for d in data:
    print(d['title']) 
# 取出每⼀一篇⽂文章的標題
# Out:
# <請先點我> 工作板＆實習、打工職缺刊登說明
# #面試經驗集中樓 分享面試心得拿✨iPhone11📱✨ 跟1111求職小幫手一起為新鮮人解惑吧😇
# 連服務工讀生都錄取不上
# 網路世代年輕人，為何不適應職場？
# 起薪140的我是否太不知足
# 月薪近6萬了，對生活還是非常不滿
# 是我太草莓還是工作不合理？
# 我是原po沒想到這麼多回應 謝謝
# 職場生活真的不一樣
# XX行銷公司實習面試踩雷
# 應屆畢業生 工作選擇（？
# 待業中的我  想去工讀
# 同事集體霸凌，真的超想一個一個抓起來練練拳頭👊🏻
# 高雄是不是很難找阿
# #分享 其實我覺得我很幸運
# 對工作不上手
# 薪水不會比較高，工作一定要很認真嗎？
# 不是你創意不好，是參考資料沒有找好！？
# 台積電 讚啦
# 台積與公職
# 餐飲	---＞郵局
# 飲料店打工離職
# 設計的真好！實際好用又省錢
# 作業員相關問題
# 作業員請進，求救...
# 到職一個月薪水慘
# 年資7年
# 五十嵐離職
# 該選擇什麼工作？
# 應屆畢業生 工作請益
